# %%
# !git clone https://github.com/rbilleci/pandora-prescriptor.git temp/pandora-prescriptor/work
# Out:
# Cloning into 'temp/pandora-prescriptor/work'...
# remote: Enumerating objects: 198, done.
# remote: Counting objects: 100% (198/198), done.
# remote: Compressing objects: 100% (137/137), done.
# remote: Total 198 (delta 88), reused 162 (delta 54), pack-reused 0
# Receiving objects: 100% (198/198), 2.21 MiB | 3.07 MiB/s, done.
# Resolving deltas: 100% (88/88), done.

# %% [markdown]
# # Generate the prescriptions

# %%
import os
os.chdir('temp/pandora-prescriptor')
print(os.getcwd())
# Out:
# /root/pandora-dashboard/temp/pandora-prescriptor

# %%
# !python work/prescribe.py -s 2021-02-01 -e 2021-05-01 \
    -ip work/pandora/data/all_2020_ips.csv \
    -c work/covid_xprize/validation/data/uniform_random_costs.csv \
    -o work/prescriptions.csv
# Out:
# quantized model ready
# Generating prescriptions from 2021-02-01 to 2021-05-01...
# prescription started @ 2021-02-10 14:21:42.534135
# prescription from 2021-02-01 to 2021-05-01
# prescription with past IPS:   work/pandora/data/all_2020_ips.csv
# prescription with past costs: work/covid_xprize/validation/data/uniform_random_costs.csv
# prescription with output to:  work/prescriptions.csv
# NumExpr defaulting to 2 threads.
# work/prescribe.py:62: DtypeWarning: Columns (2,3) have mixed types.Specify dtype option on import or set low_memory=False.
#   prescribe(args.start_date, args.end_date, args.prior_ips_file, args.cost_file, args.output_file)
# No missing data.
# initializing prescriptions generator
# prescription run 1 started @ 2021-02-10 14:21:50.217849
# Aruba__ searching for prescriptions...
# Aruba__ index [0] - 8828.504191053175 0.957259259259308 1.0
# Aruba__ index [1] - 7724.056043005435 1.6796018518518794 1.0
# Aruba__ index [2] - 6746.117710397132 2.3997592592592163 3.0
# ...

# %%
# reset the current directory
os.chdir('/')
print(os.getcwd())
# Out:
# /
